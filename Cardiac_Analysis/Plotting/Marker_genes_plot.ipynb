# %%
import scanpy as sc 
import treedata as td
import pycea as py
import matplotlib.pyplot as plt

# %% [markdown]
# Marker genes from Robin's paper

# %%
grouped_markers = {
    "Primitive_streak": ["Nanog", "Eomes", "T"],
    "Nascent_mesoderm": ["Mesp2", "Lefty2", "Tdgf1", "Mesp1"],
    "Mixed_mesoderm": ["Phlda2", "Msx1", "Msx2", "Ifitm1"],
    "Paraxial_Pharyngeal_mesoderm": ["Tcf15"],
    "ExE_mesoderm": ["Cdx1", "Cdx2", "Cdx4", "Bmp4"],
    "aSH_Pharyngeal_mesoderm": ["Isl1", "Fgf10", "Tbx1", 'Fgf8'],
    "pSHF_Pharyngeal_mesoderm": ["Osr1", "Aldh1a2", "Arg1"],
    "Mesenchyme": ["Igf2", "Krt8", "Krt18", "Pmp22", "Ahnak"],
    "JCF_Mesenchyme": ["Hand1", "Foxf1", "Mab21l2"],
    "Cardiomyocytes": ["Ttn", "Tnnt2", "Myl7", "Acta2"],
    "Hedgehog Genes": ['Shh', "Ihh", "Gli1", "Ptch1", "Hhip", "Foxf1"]
}

# %%
data_dir = "output_data"
plot_dir = "output_plot"
base_path = "/project/imoskowitz/yubin/Lineage_Tree_Construction/"
output_path_data = base_path+data_dir+"/"
output_path_plot = base_path+plot_dir+"/Celltypist_annotation/Robin_Pijuan/E8_0/Deeper_Cardiac_Annotation/"
tdata_directory = base_path + "output_data/Processed_data"

# %%
import sys
sys.path.insert(1, '/project/imoskowitz/yubin/SmoNull_NMPs_mesoderm_biased_analysis')
from src.I_preprocessing.plot_preprocessing import plot_UMAP_custom
from src.III_celltype_annotation.plot_celltype_annotation import (
    filter_marker_genes,
    get_marker_vmin_vmax,
    plot_marker_genes_feature,
    plot_markers_violin_comparison,
)

# %%
tdata_subset = td.read_h5td("/project/imoskowitz/yubin/Lineage_Tree_Construction/output_data/temp/E8_5_cardiac_subset_deeper_annotation.h5td")

# %%
tdatas = {}
from pathlib import Path
path = Path("/project/imoskowitz/yubin/Lineage_Tree_Construction/output_data/Processed_data")
for file in path.glob("*"):
    tdatas[file.stem] = td.read_h5td(file)

# %%
tdata_subset
# Out:
# TreeData object with n_obs × n_vars = 6563 × 78258
#     obs: 'cell_subtype', 'capture', 'embryo', 'stage', 'type', 'total_counts', 'pe_counts', 'detection_rate', 'edit_frac', 'clone', 'phase', 'cell_type', 'germ_layer', 'lineage', 'tree', 'leiden_0.25', 'leiden_0.5', 'leiden_1.0', 'leiden_2.0', 'Robin_celltypist_annotation', 'Robin_Pijuan_celltypist_annotation', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label', 'Robin_Pijuan_annotation_E8_0_model_top1000_low_score', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l025', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l05', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l10', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l20'
#     var: 'gene_ids', 'mito', 'chromosome', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable'
#     uns: 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l025_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l05_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l10_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l20_colors', 'Robin_Pijuan_celltypist_annotation_colors', 'Robin_celltypist_annotation_colors', 'hvg', 'leiden_0.25', 'leiden_0.25_colors', 'leiden_0.5', 'leiden_0.5_colors', 'leiden_1.0', 'leiden_1.0_colors', 'leiden_2.0', 'leiden_2.0_colors', 'leiden_names', 'log1p', 'neighbors', 'pca', 'pearson_residuals_normalization', 'top5_celltypes_Robin_Pijuan_annotation_E8_0_model_top1000_mv_label', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_scvi', 'X_umap', 'characters'
#     varm: 'PCs'
#     layers: 'Norm_count', 'raw_counts'
#     obsp: 'connectivities', 'distances'
#     obst: 'E8.0-R3-C2', 'E8.0-R2-C2', 'E8.0-R1-C2', 'E8.0-R1-C3', 'E8.0-R2-C1', 'E8.0-R3-C5', 'E8.0-R3-C1', 'E8.0-R1-C1', 'E8.0-R3-C6', 'E8.0-R3-C4', 'E8.0-R3-C3'

# %%
tdata_subset.X = tdata_subset.layers["Norm_count"]

# %%
sc.pl.umap(tdata_subset, color = "Hand2", cmap="viridis_r")

# %%
tdata_subset
# Out:
# TreeData object with n_obs × n_vars = 6563 × 78258
#     obs: 'cell_subtype', 'capture', 'embryo', 'stage', 'type', 'total_counts', 'pe_counts', 'detection_rate', 'edit_frac', 'clone', 'phase', 'cell_type', 'germ_layer', 'lineage', 'tree', 'leiden_0.25', 'leiden_0.5', 'leiden_1.0', 'leiden_2.0', 'Robin_celltypist_annotation', 'Robin_Pijuan_celltypist_annotation', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label', 'Robin_Pijuan_annotation_E8_0_model_top1000_low_score', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l025', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l05', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l10', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l20'
#     var: 'gene_ids', 'mito', 'chromosome', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable'
#     uns: 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l025_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l05_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l10_colors', 'Robin_Pijuan_annotation_E8_0_model_top1000_mv_label_mode_l20_colors', 'Robin_Pijuan_celltypist_annotation_colors', 'Robin_celltypist_annotation_colors', 'hvg', 'leiden_0.25', 'leiden_0.25_colors', 'leiden_0.5', 'leiden_0.5_colors', 'leiden_1.0', 'leiden_1.0_colors', 'leiden_2.0', 'leiden_2.0_colors', 'leiden_names', 'log1p', 'neighbors', 'pca', 'pearson_residuals_normalization', 'top5_celltypes_Robin_Pijuan_annotation_E8_0_model_top1000_mv_label', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_scvi', 'X_umap', 'characters'
#     varm: 'PCs'
#     layers: 'Norm_count', 'raw_counts'
#     obsp: 'connectivities', 'distances'
#     obst: 'E8.0-R3-C2', 'E8.0-R2-C2', 'E8.0-R1-C2', 'E8.0-R1-C3', 'E8.0-R2-C1', 'E8.0-R3-C5', 'E8.0-R3-C1', 'E8.0-R1-C1', 'E8.0-R3-C6', 'E8.0-R3-C4', 'E8.0-R3-C3'

# %% [markdown]
# #### Filter the Marker Genes

# %%
markers_filtered = filter_marker_genes(tdata_subset, grouped_markers)

# %%
markers_filtered
# Out:
# {'Primitive_streak': ['Nanog', 'Eomes', 'T'],
#  'Nascent_mesoderm': ['Mesp2', 'Lefty2', 'Mesp1'],
#  'Mixed_mesoderm': ['Phlda2', 'Msx1', 'Msx2', 'Ifitm1'],
#  'Paraxial_Pharyngeal_mesoderm': ['Tcf15'],
#  'ExE_mesoderm': ['Cdx1', 'Cdx2', 'Cdx4', 'Bmp4'],
#  'aSH_Pharyngeal_mesoderm': ['Isl1', 'Fgf10', 'Tbx1', 'Fgf8'],
#  'pSHF_Pharyngeal_mesoderm': ['Osr1', 'Aldh1a2', 'Arg1'],
#  'Mesenchyme': ['Igf2', 'Krt8', 'Krt18', 'Pmp22', 'Ahnak'],
#  'JCF_Mesenchyme': ['Hand1', 'Foxf1', 'Mab21l2'],
#  'Cardiomyocytes': ['Ttn', 'Tnnt2', 'Myl7', 'Acta2'],
#  'Hedgehog Genes': ['Shh', 'Ihh', 'Gli1', 'Ptch1', 'Hhip', 'Foxf1']}

# %% [markdown]
# #### Plotting Feature Plots

# %%
tdata_subset.X = tdata_subset.layers["Norm_count"]
markers_filtered = filter_marker_genes(tdata_subset, grouped_markers)
markers_vmin_vmax = get_marker_vmin_vmax(adata=tdata_subset, markers_filtered=markers_filtered)


plot_marker_genes_feature(
adata=tdata_subset, umap_coords_obsm="X_umap",
markers_filtered=markers_filtered,
output_path_plot=output_path_plot+"/",
markers_vmin_vmax=markers_vmin_vmax)

# %%
output_path_plot = "/project/imoskowitz/yubin/Lineage_Tree_Construction/output_plot/"
for day, tdata in tdatas.items():
    tdata.X = tdata.layers["Norm_count"]
    markers_filtered = filter_marker_genes(tdata, grouped_markers)
    markers_vmin_vmax = get_marker_vmin_vmax(tdata=tdata, markers_filtered=markers_filtered)


    plot_marker_genes_feature(
    tdata=tdata, umap_coords_obsm="X_umap",
    markers_filtered=markers_filtered,
    output_path_plot=output_path_plot+day+"/",
    markers_vmin_vmax=markers_vmin_vmax)

# %%
leiden_clusters = ['leiden_0.25', 'leiden_0.5', 'leiden_1.0', 'leiden_2.0']

# %% [markdown]
# #### Plotting Dot plot by Leiden cluster

# %%
tdata_subset.X = tdata_subset.layers["Norm_count"]
for leiden in leiden_clusters:
    sc.pl.dotplot(tdata_subset, markers_filtered, groupby=leiden,
                    show=False)
    plt.tight_layout()
    plt.savefig(output_path_plot+'leiden_dotplot/'+leiden.replace(".","_")+".png")
    # plt.close()
# Out:
# /scratch/local/jobs/52119703/ipykernel_3876187/634639986.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /scratch/local/jobs/52119703/ipykernel_3876187/634639986.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /scratch/local/jobs/52119703/ipykernel_3876187/634639986.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /scratch/local/jobs/52119703/ipykernel_3876187/634639986.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
for day, tdata in tdatas.items():
    tdata.X = tdata.layers["Norm_count"]
    for leiden in leiden_clusters:
        sc.pl.dotplot(tdata, markers_filtered, groupby=leiden,
                      show=False)
        plt.tight_layout()
        #plt.savefig(output_path_plot+'leiden/dotplot/'+day+"_cardiac_marker_gene_"+leiden.replace(".","_")+".png")
        # plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for day, tdata in tdatas.items():
#       2     tdata.X = tdata.layers["Norm_count"]
#       3     for leiden in leiden_clusters:
#
# NameError: name 'tdatas' is not defined

# %% [markdown]
# #### Violin Plots

# %%
for leiden in leiden_clusters:
    for group_name, gene_list in markers_filtered.items():
        sc.pl.stacked_violin(adata, ge, groupby='bulk_labels', dendrogram=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 for leiden in leiden_clusters:
#       2     for group_name, gene_list in markers_filtered.items():
# ----> 3         plot_markers_violin_comparison(
#       4             adata=tdata_subset, gene_list=gene_list,
#       5             gene_group_name=group_name,
#       6             output_path_plot=output_path_plot, subset_by_col=leiden
#       7         )
#
# TypeError: plot_markers_violin_comparison() missing 1 required positional argument: 'comparison_name'
